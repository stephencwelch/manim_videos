# %% [markdown]
# ## Training 4a

# %%
seed=52
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')


p=113
# seed=2 ##Set at top

lr=1e-3 #@param
p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 52)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764704101
# 0_1.5590_1.5598_pen=2.847e-02
# Saved model to /home/stephen/grokking/grok_1764704101/0.pth
# Saved model to /home/stephen/grokking/grok_1764704101/10.pth
# Saved model to /home/stephen/grokking/grok_1764704101/20.pth
# Saved model to /home/stephen/grokking/grok_1764704101/30.pth
# Saved model to /home/stephen/grokking/grok_1764704101/40.pth
# Saved model to /home/stephen/grokking/grok_1764704101/50.pth
# Saved model to /home/stephen/grokking/grok_1764704101/60.pth
# Saved model to /home/stephen/grokking/grok_1764704101/70.pth
# Saved model to /home/stephen/grokking/grok_1764704101/80.pth
# Saved model to /home/stephen/grokking/grok_1764704101/90.pth
# 100_0.6791_2.1634_pen=5.240e-02
# Saved model to /home/stephen/grokking/grok_1764704101/100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/190.pth
# 200_-3.9971_2.9172_pen=7.676e-02
# Saved model to /home/stephen/grokking/grok_1764704101/200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/290.pth
# 300_-5.0476_2.9522_pen=7.721e-02
# Saved model to /home/stephen/grokking/grok_1764704101/300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/390.pth
# 400_-6.1753_3.0121_pen=7.760e-02
# Saved model to /home/stephen/grokking/grok_1764704101/400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/490.pth
# 500_-7.2775_3.0726_pen=7.618e-02
# Saved model to /home/stephen/grokking/grok_1764704101/500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/590.pth
# 600_-8.3596_3.1318_pen=7.105e-02
# Saved model to /home/stephen/grokking/grok_1764704101/600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/690.pth
# 700_-9.4160_3.1901_pen=6.159e-02
# Saved model to /home/stephen/grokking/grok_1764704101/700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/790.pth
# 800_-10.4410_3.2463_pen=5.105e-02
# Saved model to /home/stephen/grokking/grok_1764704101/800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/890.pth
# 900_-11.4055_3.2967_pen=4.320e-02
# Saved model to /home/stephen/grokking/grok_1764704101/900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/990.pth
# 1000_-12.2327_3.3389_pen=3.452e-02
# Saved model to /home/stephen/grokking/grok_1764704101/1000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1090.pth
# 1100_-12.8759_3.3748_pen=2.324e-02
# Saved model to /home/stephen/grokking/grok_1764704101/1100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1190.pth
# 1200_-13.3866_3.4020_pen=1.397e-02
# Saved model to /home/stephen/grokking/grok_1764704101/1200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1290.pth
# 1300_-13.7883_3.4178_pen=8.857e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1390.pth
# 1400_-14.0622_3.4243_pen=6.498e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1490.pth
# 1500_-14.2212_3.4248_pen=5.417e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1590.pth
# 1600_-14.3079_3.4217_pen=4.897e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1690.pth
# 1700_-14.3538_3.4165_pen=4.627e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1790.pth
# 1800_-14.3811_3.4106_pen=4.479e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1890.pth
# 1900_-14.3968_3.4046_pen=4.388e-03
# Saved model to /home/stephen/grokking/grok_1764704101/1900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/1990.pth
# 2000_-14.4085_3.3982_pen=4.327e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2090.pth
# 2100_-14.4171_3.3921_pen=4.279e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2190.pth
# 2200_-14.4257_3.3856_pen=4.237e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2290.pth
# 2300_-14.4325_3.3789_pen=4.199e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2390.pth
# 2400_-14.4402_3.3721_pen=4.163e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2490.pth
# 2500_-14.4453_3.3646_pen=4.128e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2590.pth
# 2600_-14.4525_3.3573_pen=4.093e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2690.pth
# 2700_-14.4618_3.3494_pen=4.057e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2790.pth
# 2800_-14.4673_3.3412_pen=4.023e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2890.pth
# 2900_-14.4734_3.3327_pen=3.990e-03
# Saved model to /home/stephen/grokking/grok_1764704101/2900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/2990.pth
# 3000_-14.4774_3.3238_pen=3.953e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3090.pth
# 3100_-14.4849_3.3144_pen=3.920e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3190.pth
# 3200_-14.4915_3.3046_pen=3.885e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3290.pth
# 3300_-14.4960_3.2942_pen=3.848e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3390.pth
# 3400_-14.5067_3.2828_pen=3.811e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3490.pth
# 3500_-14.5138_3.2703_pen=3.772e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3590.pth
# 3600_-14.5208_3.2572_pen=3.733e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3690.pth
# 3700_-14.5315_3.2431_pen=3.695e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3790.pth
# 3800_-14.5380_3.2278_pen=3.655e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3890.pth
# 3900_-14.5407_3.2113_pen=3.614e-03
# Saved model to /home/stephen/grokking/grok_1764704101/3900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/3990.pth
# 4000_-14.5554_3.1940_pen=3.572e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4090.pth
# 4100_-14.5627_3.1747_pen=3.528e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4190.pth
# 4200_-14.5716_3.1539_pen=3.482e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4290.pth
# 4300_-14.5808_3.1308_pen=3.434e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4390.pth
# 4400_-14.5926_3.1054_pen=3.383e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4490.pth
# 4500_-14.6006_3.0778_pen=3.333e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4590.pth
# 4600_-14.6098_3.0475_pen=3.281e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4690.pth
# 4700_-14.6225_3.0144_pen=3.231e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4790.pth
# 4800_-14.6354_2.9780_pen=3.176e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4890.pth
# 4900_-14.6489_2.9370_pen=3.119e-03
# Saved model to /home/stephen/grokking/grok_1764704101/4900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/4990.pth
# 5000_-14.6628_2.8907_pen=3.057e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5090.pth
# 5100_-14.6782_2.8360_pen=2.991e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5190.pth
# 5200_-14.6909_2.7724_pen=2.918e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5290.pth
# 5300_-14.7163_2.6965_pen=2.840e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5390.pth
# 5400_-14.7382_2.6008_pen=2.747e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5490.pth
# 5500_-14.7655_2.4792_pen=2.640e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5590.pth
# 5600_-14.8044_2.3234_pen=2.520e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5690.pth
# 5700_-14.8435_2.1221_pen=2.386e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5790.pth
# 5800_-14.8954_1.8536_pen=2.232e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5890.pth
# 5900_-14.9587_1.4859_pen=2.063e-03
# Saved model to /home/stephen/grokking/grok_1764704101/5900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/5990.pth
# 6000_-15.0286_0.9849_pen=1.889e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6090.pth
# 6100_-15.1041_0.3433_pen=1.722e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6190.pth
# 6200_-15.1770_-0.3758_pen=1.583e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6290.pth
# 6300_-15.2288_-1.1064_pen=1.481e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6390.pth
# 6400_-15.2671_-1.8600_pen=1.402e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6490.pth
# 6500_-15.3103_-2.5822_pen=1.340e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6590.pth
# 6600_-15.3388_-3.2424_pen=1.290e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6690.pth
# 6700_-15.3638_-3.7695_pen=1.250e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6790.pth
# 6800_-15.3815_-4.1904_pen=1.220e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6890.pth
# 6900_-15.3981_-4.5273_pen=1.197e-03
# Saved model to /home/stephen/grokking/grok_1764704101/6900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/6990.pth
# 7000_-15.4084_-4.8210_pen=1.178e-03
# Saved model to /home/stephen/grokking/grok_1764704101/7000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7090.pth
# 7100_-15.4235_-5.0899_pen=1.162e-03
# Saved model to /home/stephen/grokking/grok_1764704101/7100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7190.pth
# 7200_-15.4382_-5.3705_pen=1.146e-03
# Saved model to /home/stephen/grokking/grok_1764704101/7200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/7210.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764704101/17650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17690.pth
# 17700_-11.9099_-11.0069_pen=5.235e-03
# Saved model to /home/stephen/grokking/grok_1764704101/17700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17790.pth
# 17800_-12.8763_-11.7802_pen=4.776e-03
# Saved model to /home/stephen/grokking/grok_1764704101/17800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17890.pth
# 17900_-13.7358_-12.3299_pen=3.831e-03
# Saved model to /home/stephen/grokking/grok_1764704101/17900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/17990.pth
# 18000_-14.4661_-12.8379_pen=2.663e-03
# Saved model to /home/stephen/grokking/grok_1764704101/18000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18090.pth
# 18100_-15.0523_-13.5326_pen=1.698e-03
# Saved model to /home/stephen/grokking/grok_1764704101/18100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18190.pth
# 18200_-15.4926_-14.1410_pen=1.126e-03
# Saved model to /home/stephen/grokking/grok_1764704101/18200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18290.pth
# 18300_-15.7858_-14.6200_pen=8.534e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18390.pth
# 18400_-15.9414_-14.9913_pen=7.289e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18490.pth
# 18500_-15.9959_-15.2035_pen=6.694e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18590.pth
# 18600_-16.0005_-15.2624_pen=6.414e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18690.pth
# 18700_-15.9950_-15.2744_pen=6.283e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18790.pth
# 18800_-15.9847_-15.2720_pen=6.227e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18890.pth
# 18900_-15.9755_-15.2735_pen=6.242e-04
# Saved model to /home/stephen/grokking/grok_1764704101/18900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/18990.pth
# 19000_-15.9613_-15.2664_pen=6.309e-04
# Saved model to /home/stephen/grokking/grok_1764704101/19000.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19010.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19020.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19030.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19040.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19050.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19060.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19070.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19080.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19090.pth
# 19100_-15.9477_-15.2562_pen=6.388e-04
# Saved model to /home/stephen/grokking/grok_1764704101/19100.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19110.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19120.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19130.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19140.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19150.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19160.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19170.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19180.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19190.pth
# 19200_-15.9440_-15.2539_pen=6.473e-04
# Saved model to /home/stephen/grokking/grok_1764704101/19200.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19210.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19220.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19230.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19240.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19250.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19260.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19270.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19280.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19290.pth
# 19300_-15.9317_-15.2437_pen=6.578e-04
# Saved model to /home/stephen/grokking/grok_1764704101/19300.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19310.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19320.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19330.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19340.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19350.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19360.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19370.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19380.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19390.pth
# 19400_-15.9318_-15.2424_pen=6.599e-04
# Saved model to /home/stephen/grokking/grok_1764704101/19400.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19410.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19420.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19430.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19440.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19450.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19460.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19470.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19480.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19490.pth
# 19500_-7.2867_-6.4593_pen=1.297e-03
# Saved model to /home/stephen/grokking/grok_1764704101/19500.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19510.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19520.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19530.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19540.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19550.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19560.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19570.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19580.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19590.pth
# 19600_-5.5193_-5.3195_pen=1.164e-03
# Saved model to /home/stephen/grokking/grok_1764704101/19600.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19610.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19620.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19630.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19640.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19650.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19660.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19670.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19680.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19690.pth
# 19700_-5.9988_-5.7491_pen=1.592e-03
# Saved model to /home/stephen/grokking/grok_1764704101/19700.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19710.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19720.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19730.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19740.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19750.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19760.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19770.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19780.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19790.pth
# 19800_-6.9816_-6.6460_pen=2.231e-03
# Saved model to /home/stephen/grokking/grok_1764704101/19800.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19810.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19820.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19830.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19840.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19850.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19860.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19870.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19880.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19890.pth
# 19900_-8.0121_-7.5745_pen=2.886e-03
# Saved model to /home/stephen/grokking/grok_1764704101/19900.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19910.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19920.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19930.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19940.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19950.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19960.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19970.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19980.pth
# Saved model to /home/stephen/grokking/grok_1764704101/19990.pth
# Saved model to /home/stephen/grokking/grok_1764704101/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy()
# Out:
# Original loss: 0.00017985160853967503

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:22<00:00, 23.07it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1250
# 1      448
# 6      351
# 32     285
# 49     145
# 2       45
# 12      36
# Name: count, dtype: int64

# %%
dff=df[df['kx']==6]
dff=dff[dff['ky']==6]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
#       neuron_idx  term_rank  is_dc term_type  kx  ky  amplitude     phase  \
# 1496         299          1  False     cross   6   6   0.218011  0.967969
# 1611         322          1  False     cross   6   6   0.139072 -0.060586
# 916          183          1  False     cross   6   6   0.204975  1.563937
# 946          189          1  False     cross   6   6   0.320561  0.287017
# 1156         231          1  False     cross   6   6   0.200587 -0.365188
# 246           49          1  False     cross   6   6   0.123561  1.861736
# 1381         276          1  False     cross   6   6   0.248858 -0.008361
# 536          107          1  False     cross   6   6   0.115907 -0.091655
# 1466         293          1  False     cross   6   6   0.285964 -0.183242
# 1581         316          1  False     cross   6   6   0.462944  1.015487
# 566          113          1  False     cross   6   6   0.158729  1.663953
# 171           34          1  False     cross   6   6   0.121356  0.286832
# 2116         423          1  False     cross   6   6   0.111796  0.592083
# 2256         451          1  False     cross   6   6   0.189760  0.285437
# 2311         462          1  False     cross   6   6   0.467398 -0.639386
#
#       max_amp_neuron  relative_amplitude
# 1496        0.218011                 1.0
# 1611        0.139072                 1.0
# 916         0.204975                 1.0
# 946         0.320561                 1.0
# 1156        0.200587                 1.0
# 246         0.123561                 1.0
# 1381        0.248858                 1.0
# 536         0.115907                 1.0
# 1466        0.285964                 1.0
# 1581        0.462944                 1.0
# 566         0.158729                 1.0
# 171         0.121356                 1.0
# 2116        0.111796                 1.0
# 2256        0.189760                 1.0
# 2311        0.467398                 1.0

# %%
neuron_idx=299
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.55
#     val += 0.218 * np.cos(2*np.pi*((6*i)/113) + 0.968) * np.cos(2*np.pi*((6*j)/113) + 0.968)
#     val += 0.195 * np.cos(2*np.pi*((6*i)/113) + 0.0) * np.cos(2*np.pi*((107*j)/113) + 0.0)
#     val += 0.11 * np.cos(2*np.pi*((12*i)/113) + -2.177)
#     val += 0.11 * np.cos(2*np.pi*((12*j)/113) + -2.177)
#     return val

# %%
def approx_M(i, j):
    val = 0.55
    val += 0.218 * np.cos(2*np.pi*((6*i)/113) + 0.968) * np.cos(2*np.pi*((6*j)/113) + 0.968)
    val += 0.195 * np.cos(2*np.pi*((6*i)/113) + 0.0) * np.cos(2*np.pi*((107*j)/113) + 0.0)
    val += 0.11 * np.cos(2*np.pi*((12*i)/113) + -2.177)
    val += 0.11 * np.cos(2*np.pi*((12*j)/113) + -2.177)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');

# %%
run_name
# Out:
# 'grok_1764704101'
