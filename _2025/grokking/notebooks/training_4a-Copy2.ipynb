# %% [markdown]
# ## Training 4a

# %%
seed=1
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')


p=113
# seed=2 ##Set at top

lr=1e-3 #@param
p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 2587)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764704104
# 0_1.5633_1.5625_pen=3.327e-02
# Saved model to /home/stephen/grokking/grok_1764704104/0.pth
# Saved model to /home/stephen/grokking/grok_1764704104/10.pth
# Saved model to /home/stephen/grokking/grok_1764704104/20.pth
# Saved model to /home/stephen/grokking/grok_1764704104/30.pth
# Saved model to /home/stephen/grokking/grok_1764704104/40.pth
# Saved model to /home/stephen/grokking/grok_1764704104/50.pth
# Saved model to /home/stephen/grokking/grok_1764704104/60.pth
# Saved model to /home/stephen/grokking/grok_1764704104/70.pth
# Saved model to /home/stephen/grokking/grok_1764704104/80.pth
# Saved model to /home/stephen/grokking/grok_1764704104/90.pth
# 100_0.6666_2.1087_pen=5.780e-02
# Saved model to /home/stephen/grokking/grok_1764704104/100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/190.pth
# 200_-4.1231_2.8149_pen=8.228e-02
# Saved model to /home/stephen/grokking/grok_1764704104/200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/290.pth
# 300_-5.1597_2.8398_pen=8.255e-02
# Saved model to /home/stephen/grokking/grok_1764704104/300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/390.pth
# 400_-6.2833_2.8922_pen=8.238e-02
# Saved model to /home/stephen/grokking/grok_1764704104/400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/490.pth
# 500_-7.3840_2.9480_pen=8.013e-02
# Saved model to /home/stephen/grokking/grok_1764704104/500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/590.pth
# 600_-8.4649_3.0042_pen=7.377e-02
# Saved model to /home/stephen/grokking/grok_1764704104/600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/690.pth
# 700_-9.5229_3.0587_pen=6.278e-02
# Saved model to /home/stephen/grokking/grok_1764704104/700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/790.pth
# 800_-10.5474_3.1109_pen=5.105e-02
# Saved model to /home/stephen/grokking/grok_1764704104/800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/890.pth
# 900_-11.5064_3.1571_pen=4.251e-02
# Saved model to /home/stephen/grokking/grok_1764704104/900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/990.pth
# 1000_-12.3194_3.1970_pen=3.341e-02
# Saved model to /home/stephen/grokking/grok_1764704104/1000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1090.pth
# 1100_-12.9495_3.2332_pen=2.204e-02
# Saved model to /home/stephen/grokking/grok_1764704104/1100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1190.pth
# 1200_-13.4578_3.2636_pen=1.311e-02
# Saved model to /home/stephen/grokking/grok_1764704104/1200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1290.pth
# 1300_-13.8547_3.2818_pen=8.355e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1390.pth
# 1400_-14.1246_3.2901_pen=6.183e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1490.pth
# 1500_-14.2775_3.2916_pen=5.182e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1590.pth
# 1600_-14.3605_3.2888_pen=4.699e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1690.pth
# 1700_-14.4042_3.2846_pen=4.447e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1790.pth
# 1800_-14.4307_3.2795_pen=4.306e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1890.pth
# 1900_-14.4480_3.2738_pen=4.215e-03
# Saved model to /home/stephen/grokking/grok_1764704104/1900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/1990.pth
# 2000_-14.4553_3.2682_pen=4.150e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2090.pth
# 2100_-14.4672_3.2622_pen=4.100e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2190.pth
# 2200_-14.4756_3.2559_pen=4.056e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2290.pth
# 2300_-14.4841_3.2494_pen=4.015e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2390.pth
# 2400_-14.4908_3.2429_pen=3.974e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2490.pth
# 2500_-14.4995_3.2358_pen=3.933e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2590.pth
# 2600_-14.5052_3.2281_pen=3.893e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2690.pth
# 2700_-14.5159_3.2197_pen=3.853e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2790.pth
# 2800_-14.5216_3.2105_pen=3.810e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2890.pth
# 2900_-14.5307_3.2004_pen=3.766e-03
# Saved model to /home/stephen/grokking/grok_1764704104/2900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/2990.pth
# 3000_-14.5369_3.1889_pen=3.724e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3090.pth
# 3100_-14.5495_3.1768_pen=3.680e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3190.pth
# 3200_-14.5574_3.1628_pen=3.635e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3290.pth
# 3300_-14.5610_3.1474_pen=3.589e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3390.pth
# 3400_-14.5710_3.1296_pen=3.542e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3490.pth
# 3500_-14.5800_3.1101_pen=3.491e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3590.pth
# 3600_-14.5888_3.0875_pen=3.438e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3690.pth
# 3700_-14.6035_3.0608_pen=3.379e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3790.pth
# 3800_-14.6125_3.0301_pen=3.318e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3890.pth
# 3900_-14.6270_2.9949_pen=3.252e-03
# Saved model to /home/stephen/grokking/grok_1764704104/3900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/3990.pth
# 4000_-14.6405_2.9551_pen=3.182e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4090.pth
# 4100_-14.6540_2.9105_pen=3.110e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4190.pth
# 4200_-14.6680_2.8598_pen=3.034e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4290.pth
# 4300_-14.6841_2.8022_pen=2.956e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4390.pth
# 4400_-14.7037_2.7373_pen=2.871e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4490.pth
# 4500_-14.7299_2.6613_pen=2.784e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4590.pth
# 4600_-14.7508_2.5737_pen=2.692e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4690.pth
# 4700_-14.7788_2.4648_pen=2.590e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4790.pth
# 4800_-14.8074_2.3309_pen=2.482e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4890.pth
# 4900_-14.8469_2.1605_pen=2.365e-03
# Saved model to /home/stephen/grokking/grok_1764704104/4900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/4990.pth
# 5000_-14.8917_1.9443_pen=2.242e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5090.pth
# 5100_-14.9244_1.6780_pen=2.119e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5190.pth
# 5200_-14.9904_1.3352_pen=1.998e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5290.pth
# 5300_-15.0577_0.8582_pen=1.867e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5390.pth
# 5400_-15.1242_0.1995_pen=1.727e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5490.pth
# 5500_-15.2182_-0.6495_pen=1.589e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5500.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5510.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5520.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5530.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5540.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5550.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5560.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5570.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5580.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5590.pth
# 5600_-15.2994_-1.6746_pen=1.461e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5600.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5610.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5620.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5630.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5640.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5650.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5660.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5670.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5680.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5690.pth
# 5700_-15.3612_-2.6529_pen=1.350e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5700.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5710.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5720.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5730.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5740.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5750.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5760.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5770.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5780.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5790.pth
# 5800_-15.4152_-3.4785_pen=1.263e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5890.pth
# 5900_-15.4636_-4.2940_pen=1.191e-03
# Saved model to /home/stephen/grokking/grok_1764704104/5900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/5990.pth
# 6000_-15.5053_-5.1402_pen=1.131e-03
# Saved model to /home/stephen/grokking/grok_1764704104/6000.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6010.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6020.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6030.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6040.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6050.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6060.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6070.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6080.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6090.pth
# 6100_-15.5444_-6.0539_pen=1.085e-03
# Saved model to /home/stephen/grokking/grok_1764704104/6100.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6110.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6120.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6130.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6140.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6150.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6160.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6170.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6180.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6190.pth
# 6200_-15.5699_-7.0495_pen=1.056e-03
# Saved model to /home/stephen/grokking/grok_1764704104/6200.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6210.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6220.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6230.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6240.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6250.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6260.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6270.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6280.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6290.pth
# 6300_-15.5864_-7.8723_pen=1.040e-03
# Saved model to /home/stephen/grokking/grok_1764704104/6300.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6310.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6320.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6330.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6340.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6350.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6360.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6370.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6380.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6390.pth
# 6400_-15.5997_-8.6466_pen=1.029e-03
# Saved model to /home/stephen/grokking/grok_1764704104/6400.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6410.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6420.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6430.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6440.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6450.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6460.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6470.pth
# Saved model to /home/stephen/grokking/grok_1764704104/6480.pth
# Saved model to /home/stephen/grokking/grok_1764704104/
-04
# Saved model to /home/stephen/grokking/grok_1764704104/19800.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19810.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19820.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19830.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19840.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19850.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19860.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19870.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19880.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19890.pth
# 19900_-15.7565_-14.2574_pen=9.021e-04
# Saved model to /home/stephen/grokking/grok_1764704104/19900.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19910.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19920.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19930.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19940.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19950.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19960.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19970.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19980.pth
# Saved model to /home/stephen/grokking/grok_1764704104/19990.pth
# Saved model to /home/stephen/grokking/grok_1764704104/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy()
# Out:
# Original loss: 5.170454674241454e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:21<00:00, 23.55it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1416
# 3      479
# 8      195
# 51     154
# 24     135
# 4       91
# 6       55
# 16      15
# 48      15
# 11       5
# Name: count, dtype: int64

# %%
dff=df[df['kx']==3]
dff=dff[dff['ky']==3]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
#       neuron_idx  term_rank  is_dc term_type  kx  ky  amplitude     phase  \
# 1236         247          1  False     cross   3   3   0.099431 -2.263857
# 271           54          1  False     cross   3   3   0.421388  2.807583
# 636          127          1  False     cross   3   3   0.087374 -2.378343
# 621          124          1  False     cross   3   3   0.386413 -0.133436
# 831          166          1  False     cross   3   3   0.308352  2.708271
# 601          120          1  False     cross   3   3   0.341795  2.353961
# 1286         257          1  False     cross   3   3   0.231857  1.949248
# 1356         271          1  False     cross   3   3   0.270634  1.550183
# 416           83          1  False     cross   3   3   0.202236  2.761682
# 1486         297          1  False     cross   3   3   0.241792  0.043415
# 686          137          1  False     cross   3   3   0.271055  1.906270
# 821          164          1  False     cross   3   3   0.091541  0.445334
# 2231         446          1  False     cross   3   3   0.256482 -0.413213
# 1711         342          1  False     cross   3   3   0.285591  0.848434
# 1831         366          1  False     cross   3   3   0.121620 -1.819763
#
#       max_amp_neuron  relative_amplitude
# 1236        0.099431                 1.0
# 271         0.421388                 1.0
# 636         0.087374                 1.0
# 621         0.386413                 1.0
# 831         0.308352                 1.0
# 601         0.341795                 1.0
# 1286        0.231857                 1.0
# 1356        0.270634                 1.0
# 416         0.202236                 1.0
# 1486        0.241792                 1.0
# 686         0.271055                 1.0
# 821         0.091541                 1.0
# 2231        0.256482                 1.0
# 1711        0.285591                 1.0
# 1831        0.121620                 1.0

# %%
neuron_idx=54
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.605
#     val += 0.421 * np.cos(2*np.pi*((3*i)/113) + 2.808) * np.cos(2*np.pi*((3*j)/113) + 2.808)
#     val += 0.198 * np.cos(2*np.pi*((6*i)/113) + -0.347)
#     val += 0.198 * np.cos(2*np.pi*((6*j)/113) + -0.347)
#     val += 0.065 * np.cos(2*np.pi*((3*i)/113) + 3.142) * np.cos(2*np.pi*((110*j)/113) + 3.142)
#     return val

# %%
def approx_M(i, j):
    val = 0.605
    val += 0.421 * np.cos(2*np.pi*((3*i)/113) + 2.808) * np.cos(2*np.pi*((3*j)/113) + 2.808)
    val += 0.198 * np.cos(2*np.pi*((6*i)/113) + -0.347)
    val += 0.198 * np.cos(2*np.pi*((6*j)/113) + -0.347)
    val += 0.065 * np.cos(2*np.pi*((3*i)/113) + 3.142) * np.cos(2*np.pi*((110*j)/113) + 3.142)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');

# %%
run_name
# Out:
# 'grok_1764704104'
