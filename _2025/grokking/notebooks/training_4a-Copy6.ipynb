# %% [markdown]
# ## Training 4a

# %%
seed=8527
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')



p=113
# seed=2 ##Set at top

lr=1e-3 #@param

p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.24, 1618)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3064 9705

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764704115
# 0_1.5617_1.5625_pen=2.830e-02
# Saved model to /home/stephen/grokking/grok_1764704115/0.pth
# Saved model to /home/stephen/grokking/grok_1764704115/10.pth
# Saved model to /home/stephen/grokking/grok_1764704115/20.pth
# Saved model to /home/stephen/grokking/grok_1764704115/30.pth
# Saved model to /home/stephen/grokking/grok_1764704115/40.pth
# Saved model to /home/stephen/grokking/grok_1764704115/50.pth
# Saved model to /home/stephen/grokking/grok_1764704115/60.pth
# Saved model to /home/stephen/grokking/grok_1764704115/70.pth
# Saved model to /home/stephen/grokking/grok_1764704115/80.pth
# Saved model to /home/stephen/grokking/grok_1764704115/90.pth
# 100_0.6303_2.1244_pen=4.778e-02
# Saved model to /home/stephen/grokking/grok_1764704115/100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/190.pth
# 200_-4.1640_2.8379_pen=6.729e-02
# Saved model to /home/stephen/grokking/grok_1764704115/200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/290.pth
# 300_-5.2060_2.8718_pen=6.684e-02
# Saved model to /home/stephen/grokking/grok_1764704115/300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/390.pth
# 400_-6.3279_2.9289_pen=6.624e-02
# Saved model to /home/stephen/grokking/grok_1764704115/400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/490.pth
# 500_-7.4299_2.9883_pen=6.370e-02
# Saved model to /home/stephen/grokking/grok_1764704115/500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/590.pth
# 600_-8.5122_3.0471_pen=5.794e-02
# Saved model to /home/stephen/grokking/grok_1764704115/600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/690.pth
# 700_-9.5731_3.1040_pen=4.945e-02
# Saved model to /home/stephen/grokking/grok_1764704115/700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/790.pth
# 800_-10.6028_3.1567_pen=4.187e-02
# Saved model to /home/stephen/grokking/grok_1764704115/800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/890.pth
# 900_-11.5676_3.2038_pen=3.633e-02
# Saved model to /home/stephen/grokking/grok_1764704115/900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/990.pth
# 1000_-12.3960_3.2423_pen=2.879e-02
# Saved model to /home/stephen/grokking/grok_1764704115/1000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1090.pth
# 1100_-13.0462_3.2736_pen=1.922e-02
# Saved model to /home/stephen/grokking/grok_1764704115/1100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1190.pth
# 1200_-13.5587_3.2994_pen=1.167e-02
# Saved model to /home/stephen/grokking/grok_1764704115/1200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1290.pth
# 1300_-13.9528_3.3138_pen=7.546e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1390.pth
# 1400_-14.2141_3.3174_pen=5.608e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1490.pth
# 1500_-14.3637_3.3156_pen=4.705e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1590.pth
# 1600_-14.4452_3.3111_pen=4.263e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1690.pth
# 1700_-14.4863_3.3051_pen=4.031e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1790.pth
# 1800_-14.5143_3.2983_pen=3.896e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1890.pth
# 1900_-14.5281_3.2914_pen=3.807e-03
# Saved model to /home/stephen/grokking/grok_1764704115/1900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/1990.pth
# 2000_-14.5434_3.2844_pen=3.743e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2090.pth
# 2100_-14.5502_3.2773_pen=3.692e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2190.pth
# 2200_-14.5586_3.2704_pen=3.648e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2290.pth
# 2300_-14.5646_3.2632_pen=3.605e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2390.pth
# 2400_-14.5780_3.2564_pen=3.566e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2490.pth
# 2500_-14.5824_3.2492_pen=3.527e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2590.pth
# 2600_-14.5898_3.2414_pen=3.488e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2690.pth
# 2700_-14.5988_3.2337_pen=3.449e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2790.pth
# 2800_-14.6061_3.2258_pen=3.409e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2890.pth
# 2900_-14.6158_3.2174_pen=3.369e-03
# Saved model to /home/stephen/grokking/grok_1764704115/2900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/2990.pth
# 3000_-14.6217_3.2085_pen=3.331e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3090.pth
# 3100_-14.6321_3.1995_pen=3.291e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3190.pth
# 3200_-14.6377_3.1900_pen=3.252e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3290.pth
# 3300_-14.6475_3.1794_pen=3.213e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3390.pth
# 3400_-14.6511_3.1679_pen=3.174e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3490.pth
# 3500_-14.6597_3.1563_pen=3.134e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3590.pth
# 3600_-14.6669_3.1445_pen=3.094e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3690.pth
# 3700_-14.6792_3.1321_pen=3.055e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3790.pth
# 3800_-14.6902_3.1190_pen=3.017e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3890.pth
# 3900_-14.6982_3.1052_pen=2.977e-03
# Saved model to /home/stephen/grokking/grok_1764704115/3900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/3990.pth
# 4000_-14.6965_3.0903_pen=2.935e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4090.pth
# 4100_-14.7045_3.0749_pen=2.896e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4190.pth
# 4200_-14.7167_3.0577_pen=2.854e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4290.pth
# 4300_-14.7325_3.0392_pen=2.813e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4390.pth
# 4400_-14.7289_3.0191_pen=2.774e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4490.pth
# 4500_-14.7503_2.9975_pen=2.731e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4590.pth
# 4600_-14.7449_2.9740_pen=2.688e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4690.pth
# 4700_-14.7658_2.9489_pen=2.648e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4790.pth
# 4800_-14.7700_2.9219_pen=2.606e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4890.pth
# 4900_-14.7880_2.8936_pen=2.565e-03
# Saved model to /home/stephen/grokking/grok_1764704115/4900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/4990.pth
# 5000_-14.7828_2.8632_pen=2.522e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5090.pth
# 5100_-14.7807_2.8318_pen=2.481e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5190.pth
# 5200_-14.8073_2.7972_pen=2.438e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5290.pth
# 5300_-14.8320_2.7597_pen=2.397e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5390.pth
# 5400_-14.8328_2.7205_pen=2.358e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5490.pth
# 5500_-14.8441_2.6783_pen=2.317e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5590.pth
# 5600_-14.8689_2.6334_pen=2.277e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5690.pth
# 5700_-14.8766_2.5835_pen=2.234e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5790.pth
# 5800_-14.8877_2.5297_pen=2.191e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5890.pth
# 5900_-14.8854_2.4712_pen=2.147e-03
# Saved model to /home/stephen/grokking/grok_1764704115/5900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/5990.pth
# 6000_-14.9102_2.4057_pen=2.104e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6090.pth
# 6100_-14.9365_2.3316_pen=2.062e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6100.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6110.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6120.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6130.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6140.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6150.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6160.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6170.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6180.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6190.pth
# 6200_-14.9503_2.2449_pen=2.015e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6200.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6210.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6220.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6230.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6240.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6250.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6260.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6270.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6280.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6290.pth
# 6300_-14.9462_2.1431_pen=1.967e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6300.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6310.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6320.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6330.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6340.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6350.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6360.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6370.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6380.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6390.pth
# 6400_-14.9809_2.0170_pen=1.914e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6400.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6410.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6420.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6430.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6440.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6450.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6460.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6470.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6480.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6490.pth
# 6500_-15.0094_1.8568_pen=1.856e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6500.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6510.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6520.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6530.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6540.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6550.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6560.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6570.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6580.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6590.pth
# 6600_-15.0421_1.6417_pen=1.789e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6600.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6610.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6620.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6630.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6640.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6650.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6660.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6690.pth
# 6700_-15.0960_1.3364_pen=1.710e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6790.pth
# 6800_-15.1707_0.8708_pen=1.611e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6890.pth
# 6900_-15.2254_0.2021_pen=1.494e-03
# Saved model to /home/stephen/grokking/grok_1764704115/6900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/6990.pth
# 7000_-15.3115_-0.7237_pen=1.367e-03
# Saved model to /home/stephen/grokking/grok_1764704115/7000.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7010.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7020.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7030.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7040.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7050.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7060.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7070.pth
# Saved model to /home/stephen/grokking/grok_1764704115/7080.pth
# Saved model to /home/stephen/grokking/grok_1764704115/
pth
# Saved model to /home/stephen/grokking/grok_1764704115/19670.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19680.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19690.pth
# 19700_-15.9647_-14.8802_pen=6.682e-04
# Saved model to /home/stephen/grokking/grok_1764704115/19700.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19710.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19720.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19730.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19740.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19750.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19760.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19770.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19780.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19790.pth
# 19800_-15.9613_-14.9388_pen=6.566e-04
# Saved model to /home/stephen/grokking/grok_1764704115/19800.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19810.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19820.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19830.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19840.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19850.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19860.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19870.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19880.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19890.pth
# 19900_-15.9582_-14.9854_pen=6.510e-04
# Saved model to /home/stephen/grokking/grok_1764704115/19900.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19910.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19920.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19930.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19940.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19950.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19960.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19970.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19980.pth
# Saved model to /home/stephen/grokking/grok_1764704115/19990.pth
# Saved model to /home/stephen/grokking/grok_1764704115/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy() 

# np.save(str(root/run_name)+'/mlp_hook_pre', mr)
# Out:
# Original loss: 2.5506352321984187e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:24<00:00, 21.32it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1079
# 4      573
# 27     454
# 3      335
# 6       64
# 8       28
# 54      27
# Name: count, dtype: int64

# %%
dff=df[df['kx']==4]
dff=dff[dff['ky']==4]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
#       neuron_idx  term_rank  is_dc term_type  kx  ky  amplitude     phase  \
# 2366         473          1  False     cross   4   4   0.475796 -3.011523
# 593          118          3  False     cross   4   4   0.601408  2.451129
# 323           64          3  False     cross   4   4   0.269974 -3.092258
# 1098         219          3  False     cross   4   4   0.179304  0.133846
# 348           69          3  False     cross   4   4   0.154058 -0.115037
# 2129         425          4  False     cross   4   4   0.176263 -0.618214
# 1903         380          3  False     cross   4   4   0.109893 -1.034550
# 2004         400          4  False     cross   4   4   0.089673 -1.938318
# 1268         253          3  False     cross   4   4   0.142904 -1.324998
# 724          144          4  False     cross   4   4   0.109485 -0.894842
# 524          104          4  False     cross   4   4   0.150143  0.590070
# 948          189          3  False     cross   4   4   0.139482 -0.049226
# 2294         458          4  False     cross   4   4   0.202923  0.928070
# 1753         350          3  False     cross   4   4   0.148680 -0.574173
# 1033         206          3  False     cross   4   4   0.146483 -1.349538
#
#       max_amp_neuron  relative_amplitude
# 2366        0.475796            1.000000
# 593         0.842553            0.713792
# 323         0.424935            0.635329
# 1098        0.288907            0.620629
# 348         0.260205            0.592064
# 2129        0.301979            0.583691
# 1903        0.190081            0.578135
# 2004        0.155426            0.576949
# 1268        0.248000            0.576224
# 724         0.190070            0.576023
# 524         0.262014            0.573034
# 948         0.243809            0.572096
# 2294        0.366214            0.554110
# 1753        0.286932            0.518172
# 1033        0.284472            0.514931

# %%
neuron_idx=219
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.795
#     val += 0.289 * np.cos(2*np.pi*((4*i)/113) + 1.103)
#     val += 0.288 * np.cos(2*np.pi*((4*j)/113) + 1.096)
#     val += 0.179 * np.cos(2*np.pi*((4*i)/113) + 0.134) * np.cos(2*np.pi*((4*j)/113) + 0.134)
#     val += 0.105 * np.cos(2*np.pi*((8*j)/113) + -2.984)
#     return val

# %%
def approx_M(i, j):
    val = 0.795
    val += 0.289 * np.cos(2*np.pi*((4*i)/113) + 1.103)
    val += 0.288 * np.cos(2*np.pi*((4*j)/113) + 1.096)
    val += 0.179 * np.cos(2*np.pi*((4*i)/113) + 0.134) * np.cos(2*np.pi*((4*j)/113) + 0.134)
    val += 0.105 * np.cos(2*np.pi*((8*j)/113) + -2.984)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');
