# %% [markdown]
# ## Training 4a

# %%
seed=25
frac_train=0.25 
weight_decay = 1.0 #@param
freq_penalty_weight = 1e-3

# %%
# Import stuff
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import einops
import tqdm.notebook as tqdm

import random
import time

# from google.colab import drive
from pathlib import Path
import pickle
import os

import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "colab"
import plotly.graph_objects as go

from torch.utils.data import DataLoader

from functools import *
import pandas as pd
import gc

# import comet_ml
import itertools

# %% [markdown]
# ## Support Functions

# %%
# A helper class to get access to intermediate activations (inspired by Garcon)
# It's a dummy module that is the identity function by default
# I can wrap any intermediate activation in a HookPoint and get a convenient 
# way to add PyTorch hooks
class HookPoint(nn.Module):
    def __init__(self):
        super().__init__()
        self.fwd_hooks = []
        self.bwd_hooks = []
    
    def give_name(self, name):
        # Called by the model at initialisation
        self.name = name
    
    def add_hook(self, hook, dir='fwd'):
        # Hook format is fn(activation, hook_name)
        # Change it into PyTorch hook format (this includes input and output, 
        # which are the same for a HookPoint)
        def full_hook(module, module_input, module_output):
            return hook(module_output, name=self.name)
        if dir=='fwd':
            handle = self.register_forward_hook(full_hook)
            self.fwd_hooks.append(handle)
        elif dir=='bwd':
            handle = self.register_backward_hook(full_hook)
            self.bwd_hooks.append(handle)
        else:
            raise ValueError(f"Invalid direction {dir}")
    
    def remove_hooks(self, dir='fwd'):
        if (dir=='fwd') or (dir=='both'):
            for hook in self.fwd_hooks:
                hook.remove()
            self.fwd_hooks = []
        if (dir=='bwd') or (dir=='both'):
            for hook in self.bwd_hooks:
                hook.remove()
            self.bwd_hooks = []
        if dir not in ['fwd', 'bwd', 'both']:
            raise ValueError(f"Invalid direction {dir}")
    
    def forward(self, x):
        return x

# %%
# Define network architecture
# I defined my own transformer from scratch so I'd fully understand each component 
# - I expect this wasn't necessary or particularly important, and a bunch of this 
# replicates existing PyTorch functionality

# Embed & Unembed
class Embed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_E = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_model))
    
    def forward(self, x):
        return torch.einsum('dbp -> bpd', self.W_E[:, x])

class Unembed(nn.Module):
    def __init__(self, d_vocab, d_model):
        super().__init__()
        self.W_U = nn.Parameter(torch.randn(d_model, d_vocab)/np.sqrt(d_vocab))
    
    def forward(self, x):
        return (x @ self.W_U)

# Positional Embeddings
class PosEmbed(nn.Module):
    def __init__(self, max_ctx, d_model):
        super().__init__()
        self.W_pos = nn.Parameter(torch.randn(max_ctx, d_model)/np.sqrt(d_model))
    
    def forward(self, x):
        return x+self.W_pos[:x.shape[-2]]

# LayerNorm
class LayerNorm(nn.Module):
    def __init__(self, d_model, epsilon = 1e-4, model=[None]):
        super().__init__()
        self.model = model
        self.w_ln = nn.Parameter(torch.ones(d_model))
        self.b_ln = nn.Parameter(torch.zeros(d_model))
        self.epsilon = epsilon
    
    def forward(self, x):
        if self.model[0].use_ln:
            x = x - x.mean(axis=-1)[..., None]
            x = x / (x.std(axis=-1)[..., None] + self.epsilon)
            x = x * self.w_ln
            x = x + self.b_ln
            return x
        else:
            return x

# Attention
class Attention(nn.Module):
    def __init__(self, d_model, num_heads, d_head, n_ctx, model):
        super().__init__()
        self.model = model
        self.W_K = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_Q = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_V = nn.Parameter(torch.randn(num_heads, d_head, d_model)/np.sqrt(d_model))
        self.W_O = nn.Parameter(torch.randn(d_model, d_head * num_heads)/np.sqrt(d_model))
        self.register_buffer('mask', torch.tril(torch.ones((n_ctx, n_ctx))))
        self.d_head = d_head
        self.hook_k = HookPoint()
        self.hook_q = HookPoint()
        self.hook_v = HookPoint()
        self.hook_z = HookPoint()
        self.hook_attn = HookPoint()
        self.hook_attn_pre = HookPoint()

    def forward(self, x):
        k = self.hook_k(torch.einsum('ihd,bpd->biph', self.W_K, x))
        q = self.hook_q(torch.einsum('ihd,bpd->biph', self.W_Q, x))
        v = self.hook_v(torch.einsum('ihd,bpd->biph', self.W_V, x))
        attn_scores_pre = torch.einsum('biph,biqh->biqp', k, q)
        attn_scores_masked = torch.tril(attn_scores_pre) - 1e10 * (1 - self.mask[:x.shape[-2], :x.shape[-2]])
        attn_matrix = self.hook_attn(F.softmax(self.hook_attn_pre(attn_scores_masked/np.sqrt(self.d_head)), dim=-1))
        z = self.hook_z(torch.einsum('biph,biqp->biqh', v, attn_matrix))
        z_flat = einops.rearrange(z, 'b i q h -> b q (i h)')
        out = torch.einsum('df,bqf->bqd', self.W_O, z_flat)
        return out

# MLP Layers
class MLP(nn.Module):
    def __init__(self, d_model, d_mlp, act_type, model):
        super().__init__()
        self.model = model
        self.W_in = nn.Parameter(torch.randn(d_mlp, d_model)/np.sqrt(d_model))
        self.b_in = nn.Parameter(torch.zeros(d_mlp))
        self.W_out = nn.Parameter(torch.randn(d_model, d_mlp)/np.sqrt(d_model))
        self.b_out = nn.Parameter(torch.zeros(d_model))
        self.act_type = act_type
        # self.ln = LayerNorm(d_mlp, model=self.model)
        self.hook_pre = HookPoint()
        self.hook_post = HookPoint()
        assert act_type in ['ReLU', 'GeLU']
        
    def forward(self, x):
        x = self.hook_pre(torch.einsum('md,bpd->bpm', self.W_in, x) + self.b_in)
        if self.act_type=='ReLU':
            x = F.relu(x)
        elif self.act_type=='GeLU':
            x = F.gelu(x)
        x = self.hook_post(x)
        x = torch.einsum('dm,bpm->bpd', self.W_out, x) + self.b_out
        return x

# Transformer Block
class TransformerBlock(nn.Module):
    def __init__(self, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model):
        super().__init__()
        self.model = model
        # self.ln1 = LayerNorm(d_model, model=self.model)
        self.attn = Attention(d_model, num_heads, d_head, n_ctx, model=self.model)
        # self.ln2 = LayerNorm(d_model, model=self.model)
        self.mlp = MLP(d_model, d_mlp, act_type, model=self.model)
        self.hook_attn_out = HookPoint()
        self.hook_mlp_out = HookPoint()
        self.hook_resid_pre = HookPoint()
        self.hook_resid_mid = HookPoint()
        self.hook_resid_post = HookPoint()
    
    def forward(self, x):
        x = self.hook_resid_mid(x + self.hook_attn_out(self.attn((self.hook_resid_pre(x)))))
        x = self.hook_resid_post(x + self.hook_mlp_out(self.mlp((x))))
        return x

# Full transformer
class Transformer(nn.Module):
    def __init__(self, num_layers, d_vocab, d_model, d_mlp, d_head, num_heads, n_ctx, act_type, use_cache=False, use_ln=True):
        super().__init__()
        self.cache = {}
        self.use_cache = use_cache

        self.embed = Embed(d_vocab, d_model)
        self.pos_embed = PosEmbed(n_ctx, d_model)
        self.blocks = nn.ModuleList([TransformerBlock(d_model, d_mlp, d_head, num_heads, n_ctx, act_type, model=[self]) for i in range(num_layers)])
        # self.ln = LayerNorm(d_model, model=[self])
        self.unembed = Unembed(d_vocab, d_model)
        self.use_ln = use_ln

        for name, module in self.named_modules():
            if type(module)==HookPoint:
                module.give_name(name)
    
    def forward(self, x):
        x = self.embed(x)
        x = self.pos_embed(x)
        for block in self.blocks:
            x = block(x)
        # x = self.ln(x)
        x = self.unembed(x)
        return x

    def set_use_cache(self, use_cache):
        self.use_cache = use_cache
    
    def hook_points(self):
        return [module for name, module in self.named_modules() if 'hook' in name]

    def remove_all_hooks(self):
        for hp in self.hook_points():
            hp.remove_hooks('fwd')
            hp.remove_hooks('bwd')
    
    def cache_all(self, cache, incl_bwd=False):
        # Caches all activations wrapped in a HookPoint
        def save_hook(tensor, name):
            cache[name] = tensor.detach()
        def save_hook_back(tensor, name):
            cache[name+'_grad'] = tensor[0].detach()
        for hp in self.hook_points():
            hp.add_hook(save_hook, 'fwd')
            if incl_bwd:
                hp.add_hook(save_hook_back, 'bwd')

# %%
# Helper functions
def cuda_memory():
    print(torch.cuda.memory_allocated()/1e9)

def cross_entropy_high_precision(logits, labels):
    # Shapes: batch x vocab, batch
    # Cast logits to float64 because log_softmax has a float32 underflow on overly 
    # confident data and can only return multiples of 1.2e-7 (the smallest float x
    # such that 1+x is different from 1 in float32). This leads to loss spikes 
    # and dodgy gradients
    logprobs = F.log_softmax(logits.to(torch.float64), dim=-1)
    prediction_logprobs = torch.gather(logprobs, index=labels[:, None], dim=-1)
    loss = -torch.mean(prediction_logprobs)
    return loss

def full_loss(model, data):
    # Take the final position only
    logits = model(data)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in data]).to('cuda')
    return cross_entropy_high_precision(logits, labels)

def test_logits(logits, bias_correction=False, original_logits=None, mode='all'):
    # Calculates cross entropy loss of logits representing a batch of all p^2 
    # possible inputs
    # Batch dimension is assumed to be first
    if logits.shape[1]==p*p:
        logits = logits.T
    if logits.shape==torch.Size([p*p, p+1]):
        logits = logits[:, :-1]
    logits = logits.reshape(p*p, p)
    if bias_correction:
        # Applies bias correction - we correct for any missing bias terms, 
        # independent of the input, by centering the new logits along the batch 
        # dimension, and then adding the average original logits across all inputs
        logits = einops.reduce(original_logits - logits, 'batch ... -> ...', 'mean') + logits
    if mode=='train':
        return cross_entropy_high_precision(logits[is_train], labels[is_train])
    elif mode=='test':
        return cross_entropy_high_precision(logits[is_test], labels[is_test])
    elif mode=='all':
        return cross_entropy_high_precision(logits, labels)

def unflatten_first(tensor):
    if tensor.shape[0]==p*p:
        return einops.rearrange(tensor, '(x y) ... -> x y ...', x=p, y=p)
    else: 
        return tensor
def cos(x, y):
    return (x.dot(y))/x.norm()/y.norm()
def mod_div(a, b):
    return (a*pow(b, p-2, p))%p
def normalize(tensor, axis=0):
    return tensor/(tensor).pow(2).sum(keepdim=True, axis=axis).sqrt()
def extract_freq_2d(tensor, freq):
    # Takes in a pxpx... or batch x ... tensor, returns a 3x3x... tensor of the 
    # Linear and quadratic terms of frequency freq
    tensor = unflatten_first(tensor)
    # Extracts the linear and quadratic terms corresponding to frequency freq
    index_1d = [0, 2*freq-1, 2*freq]
    # Some dumb manipulation to use fancy array indexing rules
    # Gets the rows and columns in index_1d
    return tensor[[[i]*3 for i in index_1d], [index_1d]*3]
def get_cov(tensor, norm=True):
    # Calculate covariance matrix
    if norm:
        tensor = normalize(tensor, axis=1)
    return tensor @ tensor.T
def is_close(a, b):
    return ((a-b).pow(2).sum()/(a.pow(2).sum().sqrt())/(b.pow(2).sum().sqrt())).item()

# %%
def compute_frequency_components(m):
    """
    Compute canonical frequency components of a real 2D signal m using fft2.

    Returns:
        components: list of dicts with keys:
            - 'kx': frequency index in x (rows)
            - 'ky': frequency index in y (cols)
            - 'coeff': complex FFT coefficient at (kx, ky)
        Nx, Ny: dimensions of the input
    """
    m = np.asarray(m)
    Nx, Ny = m.shape
    F = np.fft.fft2(m)

    components = []
    seen = set()

    for kx in range(Nx):
        for ky in range(Ny):
            # Conjugate partner indices for real-valued input
            kx_conj = (-kx) % Nx
            ky_conj = (-ky) % Ny

            pair = tuple(sorted([(kx, ky), (kx_conj, ky_conj)]))
            if pair in seen:
                continue
            seen.add(pair)

            # Always store the "smaller" one in lexicographic order
            kx_rep, ky_rep = pair[0]
            coeff = F[kx_rep, ky_rep]
            components.append({
                "kx": kx_rep,
                "ky": ky_rep,
                "coeff": coeff
            })

    return components, Nx, Ny


def components_to_terms(components, Nx, Ny, num_freqs, include_dc=True):
    """
    Convert FFT components into real cosine terms with amplitude & phase.

    Args:
        components: output from compute_frequency_components
        Nx, Ny: grid size
        num_freqs: number of *non-DC* frequencies to keep
        include_dc: whether to include the constant (DC) term

    Returns:
        terms: list of dicts with keys:
            - 'kx', 'ky'
            - 'amplitude'  (real, >= 0)
            - 'phase'      (in radians)
            - 'is_dc'      (bool, True only for the constant term)
    """
    terms = []
    dc_term = None

    for c in components:
        kx = c["kx"]
        ky = c["ky"]
        coeff = c["coeff"]

        # DC component (constant offset)
        if kx == 0 and ky == 0:
            dc_value = coeff.real / (Nx * Ny)
            dc_term = {
                "kx": 0,
                "ky": 0,
                "amplitude": dc_value,  # directly the constant offset
                "phase": 0.0,
                "is_dc": True,
            }
        else:
            # For real signals, combine (k, l) and (-k, -l) into:
            #   2*|F|/(Nx*Ny) * cos(2π(kx i/Nx + ky j/Ny) + phase)
            amp = 2.0 * np.abs(coeff) / (Nx * Ny)
            phase = np.angle(coeff)
            terms.append({
                "kx": kx,
                "ky": ky,
                "amplitude": amp,
                "phase": phase,
                "is_dc": False,
            })

    # Sort non-DC terms by amplitude (largest first)
    terms.sort(key=lambda t: t["amplitude"], reverse=True)

    # Keep only the top num_freqs
    terms = terms[:num_freqs]

    # Optionally prepend DC term
    if include_dc and dc_term is not None:
        terms = [dc_term] + terms

    return terms

def generate_python_reconstructor(terms, Nx, Ny, func_name="recon_func", decimals=4):
    """
    Generate a Python function as a string that reconstructs the signal
    using explicit 1D and product-of-cosine terms from a sparse Fourier representation.

    Types of terms:
      - DC term (constant)
      - Row-only:   A * cos(2π * (kx*i/Nx) + φ)
      - Col-only:   B * cos(2π * (ky*j/Ny) + φ)
      - Product:    C * cos(2π * (kx*i/Nx) + φ) * cos(2π * (ky*j/Ny) + φ)

    You must have `import numpy as np` in the scope where you paste/run this.
    """
    lines = []
    lines.append(f"def {func_name}(i, j):")

    if not terms:
        lines.append("    return 0.0")
        return "\n".join(lines)

    # Separate DC from others
    dc_terms = [t for t in terms if t.get("is_dc", False)]
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]

    if dc_terms:
        dc_val = round(dc_terms[0]["amplitude"], decimals)
        lines.append(f"    val = {dc_val}")
    else:
        lines.append("    val = 0.0")

    for t in non_dc_terms:
        kx, ky = t["kx"], t["ky"]
        A = round(t["amplitude"], decimals)
        phi = round(t["phase"], decimals)

        if A == 0:
            continue

        if kx != 0 and ky == 0:
            # Row-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
            )
        elif kx == 0 and ky != 0:
            # Column-only cosine
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )
        else:
            # Product-of-cosines term (your desired "third" type)
            line = (
                f"    val += {A} * np.cos(2*np.pi*(({kx}*i)/{Nx}) + {phi})"
                f" * np.cos(2*np.pi*(({ky}*j)/{Ny}) + {phi})"
            )

        lines.append(line)

    lines.append("    return val")

    return "\n".join(lines)

# %%
def set_seed(seed):
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed) # For all CUDA devices
        np.random.seed(seed)
        random.seed(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False # Set to False for determinism

# %%
def embedding_frequency_penalty(model: Transformer) -> torch.Tensor:
    """
    Encourage neighboring tokens in the embedding space to be similar.
    This is a graph-Laplacian-style smoothness penalty on W_E, which
    corresponds to penalizing high-frequency Fourier modes on Z_p.

    W_E has shape [d_model, d_vocab].
    We smooth along the vocab dimension (the modular arithmetic axis).
    """
    E = model.embed.W_E  # [d_model, d_vocab]

    # Differences between consecutive tokens (0-1, 1-2, ..., (V-2)-(V-1))
    diff = E[:, 1:] - E[:, :-1]  # [d_model, d_vocab-1]

    # Wrap-around difference to respect modular structure: token V-1 vs 0
    wrap = E[:, :1] - E[:, -1:]  # [d_model, 1]

    # Mean squared differences (Laplacian smoothness)
    penalty = (diff.pow(2).mean() + wrap.pow(2).mean())
    return penalty

# %% [markdown]
# ## Hyperparameters

# %%
root = Path('/home/stephen/grokking')



p=113
# seed=2 ##Set at top

lr=1e-3 #@param

p=113 #@param
d_model = 128 #@param
fn_name = 'add' #@param ['add', 'subtract', 'x2xyy2','rand']
num_epochs = 20000 #@param
save_models = True #@param
save_every = 10 # Maybe crank this down
# Stop training when test loss is <stopping_thresh
stopping_thresh = -1 #@param

num_layers = 1
batch_style = 'full'
d_vocab = p+1
n_ctx = 3
d_mlp = 4*d_model
num_heads = 4
assert d_model % num_heads == 0
d_head = d_model//num_heads
act_type = 'ReLU' #@param ['ReLU', 'GeLU']
# batch_size = 512
use_ln = False
random_answers = np.random.randint(low=0, high=p, size=(p, p))
fns_dict = {'add': lambda x,y:(x+y)%p, 'subtract': lambda x,y:(x-y)%p, 'x2xyy2':lambda x,y:(x**2+x*y+y**2)%p, 'rand':lambda x,y:random_answers[x][y]}
fn = fns_dict[fn_name]

# %%
frac_train, seed
# Out:
# (0.25, 25)

# %%
def gen_train_test(frac_train, num, seed=0):
    # Generate train and test split
    pairs = [(i, j, num) for i in range(num) for j in range(num)]
    random.seed(seed)
    random.shuffle(pairs)
    div = int(frac_train*len(pairs))
    return pairs[:div], pairs[div:]

train, test = gen_train_test(frac_train, p, seed)
print(len(train), len(test))
# Out:
# 3192 9577

# %%
# Creates an array of Boolean indices according to whether each data point is in 
# train or test
# Used to index into the big batch of all possible data
is_train = []
is_test = []
for x in range(p):
    for y in range(p):
        if (x, y, 113) in train:
            is_train.append(True)
            is_test.append(False)
        else:
            is_train.append(False)
            is_test.append(True)
is_train = np.array(is_train)
is_test = np.array(is_test)

# %% [markdown]
# ## Training Loop

# %%
set_seed(seed)
model = Transformer(num_layers=num_layers, d_vocab=d_vocab, d_model=d_model, d_mlp=d_mlp, d_head=d_head, num_heads=num_heads, n_ctx=n_ctx, act_type=act_type, use_cache=False, use_ln=use_ln)
model.to('cuda')
optimizer = optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay, betas=(0.9, 0.98))
scheduler = optim.lr_scheduler.LambdaLR(optimizer, lambda step: min(step/10, 1))
run_name = f"grok_{int(time.time())}"
print(f'Run name {run_name}')
if save_models:
    os.mkdir(root/run_name)
    save_dict = {'model':model.state_dict(), 'train_data':train, 'test_data':test}
    torch.save(save_dict, root/run_name/'init.pth')
train_losses = []
test_losses = []
train_accs = []
test_accs = []
for epoch in range(num_epochs):

    # 1. Compute base cross-entropy losses (no regularization)
    train_ce_loss = full_loss(model, train)
    test_loss = full_loss(model, test)  # leave test as-is

    # 2. Compute smoothness / frequency penalty on embeddings
    freq_pen = embedding_frequency_penalty(model)

    # 3. Total train loss = CE + λ * penalty
    train_loss = train_ce_loss + freq_penalty_weight * freq_pen

    # 4. Track (usually you want to log CE only for grokking plots)
    train_losses.append(train_ce_loss.item())
    test_losses.append(test_loss.item())

    logits = model(train)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in train]).to('cuda')
    train_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    train_accs.append(train_acc)
    
    logits = model(test)[:, -1]
    labels = torch.tensor([fn(i, j) for i, j, _ in test]).to('cuda')
    test_acc=((logits.detach().cpu().argmax(1)==labels.detach().cpu()).sum()/len(labels)).item()
    test_accs.append(test_acc)

    if epoch % 100 == 0:
        print(
            f"{epoch}_"
            f"{np.log(train_ce_loss.item()):.4f}_"
            f"{np.log(test_loss.item()):.4f}_"
            f"pen={freq_pen.item():.3e}"
        )

    # 5. Backprop / step
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    optimizer.zero_grad()
    if test_loss.item() < stopping_thresh:
        break
    if (save_models) and (epoch%save_every == 0):
        if test_loss.item() < stopping_thresh:
            break
        save_dict = {
            'model': model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'scheduler': scheduler.state_dict(),
            'train_loss': train_loss,
            'test_loss': test_loss,
            'epoch': epoch,
        }
        torch.save(save_dict, root/run_name/f"{epoch}.pth")
        print(f"Saved model to {root/run_name/f'{epoch}.pth'}")
if not save_models:
    os.mkdir(root/run_name)
save_dict = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'scheduler': scheduler.state_dict(),
    'train_loss': train_loss,
    'test_loss': test_loss,
    'train_losses': train_losses,
    'test_losses': test_losses,
    'train_accs': train_accs,
    'test_accs':test_accs,
    'epoch': epoch,
}
torch.save(save_dict, root/run_name/f"final.pth")
print(f"Saved model to {root/run_name/f'final.pth'}")

# save_models = False
# Out:
# Run name grok_1764704097
# 0_1.5621_1.5628_pen=3.067e-02
# Saved model to /home/stephen/grokking/grok_1764704097/0.pth
# Saved model to /home/stephen/grokking/grok_1764704097/10.pth
# Saved model to /home/stephen/grokking/grok_1764704097/20.pth
# Saved model to /home/stephen/grokking/grok_1764704097/30.pth
# Saved model to /home/stephen/grokking/grok_1764704097/40.pth
# Saved model to /home/stephen/grokking/grok_1764704097/50.pth
# Saved model to /home/stephen/grokking/grok_1764704097/60.pth
# Saved model to /home/stephen/grokking/grok_1764704097/70.pth
# Saved model to /home/stephen/grokking/grok_1764704097/80.pth
# Saved model to /home/stephen/grokking/grok_1764704097/90.pth
# 100_0.6998_2.1451_pen=5.292e-02
# Saved model to /home/stephen/grokking/grok_1764704097/100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/190.pth
# 200_-3.9948_2.9047_pen=7.486e-02
# Saved model to /home/stephen/grokking/grok_1764704097/200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/210.pth
# Saved model to /home/stephen/grokking/grok_1764704097/220.pth
# Saved model to /home/stephen/grokking/grok_1764704097/230.pth
# Saved model to /home/stephen/grokking/grok_1764704097/240.pth
# Saved model to /home/stephen/grokking/grok_1764704097/250.pth
# Saved model to /home/stephen/grokking/grok_1764704097/260.pth
# Saved model to /home/stephen/grokking/grok_1764704097/270.pth
# Saved model to /home/stephen/grokking/grok_1764704097/280.pth
# Saved model to /home/stephen/grokking/grok_1764704097/290.pth
# 300_-5.0430_2.9389_pen=7.482e-02
# Saved model to /home/stephen/grokking/grok_1764704097/300.pth
# Saved model to /home/stephen/grokking/grok_1764704097/310.pth
# Saved model to /home/stephen/grokking/grok_1764704097/320.pth
# Saved model to /home/stephen/grokking/grok_1764704097/330.pth
# Saved model to /home/stephen/grokking/grok_1764704097/340.pth
# Saved model to /home/stephen/grokking/grok_1764704097/350.pth
# Saved model to /home/stephen/grokking/grok_1764704097/360.pth
# Saved model to /home/stephen/grokking/grok_1764704097/370.pth
# Saved model to /home/stephen/grokking/grok_1764704097/380.pth
# Saved model to /home/stephen/grokking/grok_1764704097/390.pth
# 400_-6.1665_2.9981_pen=7.439e-02
# Saved model to /home/stephen/grokking/grok_1764704097/400.pth
# Saved model to /home/stephen/grokking/grok_1764704097/410.pth
# Saved model to /home/stephen/grokking/grok_1764704097/420.pth
# Saved model to /home/stephen/grokking/grok_1764704097/430.pth
# Saved model to /home/stephen/grokking/grok_1764704097/440.pth
# Saved model to /home/stephen/grokking/grok_1764704097/450.pth
# Saved model to /home/stephen/grokking/grok_1764704097/460.pth
# Saved model to /home/stephen/grokking/grok_1764704097/470.pth
# Saved model to /home/stephen/grokking/grok_1764704097/480.pth
# Saved model to /home/stephen/grokking/grok_1764704097/490.pth
# 500_-7.2661_3.0589_pen=7.236e-02
# Saved model to /home/stephen/grokking/grok_1764704097/500.pth
# Saved model to /home/stephen/grokking/grok_1764704097/510.pth
# Saved model to /home/stephen/grokking/grok_1764704097/520.pth
# Saved model to /home/stephen/grokking/grok_1764704097/530.pth
# Saved model to /home/stephen/grokking/grok_1764704097/540.pth
# Saved model to /home/stephen/grokking/grok_1764704097/550.pth
# Saved model to /home/stephen/grokking/grok_1764704097/560.pth
# Saved model to /home/stephen/grokking/grok_1764704097/570.pth
# Saved model to /home/stephen/grokking/grok_1764704097/580.pth
# Saved model to /home/stephen/grokking/grok_1764704097/590.pth
# 600_-8.3468_3.1190_pen=6.688e-02
# Saved model to /home/stephen/grokking/grok_1764704097/600.pth
# Saved model to /home/stephen/grokking/grok_1764704097/610.pth
# Saved model to /home/stephen/grokking/grok_1764704097/620.pth
# Saved model to /home/stephen/grokking/grok_1764704097/630.pth
# Saved model to /home/stephen/grokking/grok_1764704097/640.pth
# Saved model to /home/stephen/grokking/grok_1764704097/650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/690.pth
# 700_-9.4065_3.1763_pen=5.736e-02
# Saved model to /home/stephen/grokking/grok_1764704097/700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/790.pth
# 800_-10.4374_3.2297_pen=4.727e-02
# Saved model to /home/stephen/grokking/grok_1764704097/800.pth
# Saved model to /home/stephen/grokking/grok_1764704097/810.pth
# Saved model to /home/stephen/grokking/grok_1764704097/820.pth
# Saved model to /home/stephen/grokking/grok_1764704097/830.pth
# Saved model to /home/stephen/grokking/grok_1764704097/840.pth
# Saved model to /home/stephen/grokking/grok_1764704097/850.pth
# Saved model to /home/stephen/grokking/grok_1764704097/860.pth
# Saved model to /home/stephen/grokking/grok_1764704097/870.pth
# Saved model to /home/stephen/grokking/grok_1764704097/880.pth
# Saved model to /home/stephen/grokking/grok_1764704097/890.pth
# 900_-11.4098_3.2772_pen=3.976e-02
# Saved model to /home/stephen/grokking/grok_1764704097/900.pth
# Saved model to /home/stephen/grokking/grok_1764704097/910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/990.pth
# 1000_-12.2548_3.3151_pen=3.164e-02
# Saved model to /home/stephen/grokking/grok_1764704097/1000.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1010.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1020.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1030.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1040.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1050.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1060.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1070.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1080.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1090.pth
# 1100_-12.9215_3.3463_pen=2.137e-02
# Saved model to /home/stephen/grokking/grok_1764704097/1100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1190.pth
# 1200_-13.4499_3.3696_pen=1.297e-02
# Saved model to /home/stephen/grokking/grok_1764704097/1200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1210.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1220.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1230.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1240.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1250.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1260.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1270.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1280.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1290.pth
# 1300_-13.8609_3.3798_pen=8.248e-03
# Saved model to /home/stephen/grokking/grok_1764704097/1300.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1310.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1320.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1330.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1340.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1350.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1360.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1370.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1380.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1390.pth
# 1400_-14.1392_3.3798_pen=6.010e-03
# Saved model to /home/stephen/grokking/grok_1764704097/1400.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1410.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1420.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1430.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1440.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1450.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1460.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1470.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1480.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1490.pth
# 1500_-14.3032_3.3730_pen=4.964e-03
# Saved model to /home/stephen/grokking/grok_1764704097/1500.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1510.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1520.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1530.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1540.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1550.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1560.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1570.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1580.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1590.pth
# 1600_-14.3942_3.3626_pen=4.444e-03
# Saved model to /home/stephen/grokking/grok_1764704097/1600.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1610.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1620.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1630.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1640.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1690.pth
# 1700_-14.4446_3.3501_pen=4.163e-03
# Saved model to /home/stephen/grokking/grok_1764704097/1700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/1780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/
.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/5990.pth
# 6000_-15.4827_-4.8840_pen=1.112e-03
# Saved model to /home/stephen/grokking/grok_1764704097/6000.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6010.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6020.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6030.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6040.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6050.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6060.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6070.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6080.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6090.pth
# 6100_-15.5492_-5.9887_pen=1.037e-03
# Saved model to /home/stephen/grokking/grok_1764704097/6100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6190.pth
# 6200_-15.6186_-7.3976_pen=9.734e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6210.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6220.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6230.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6240.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6250.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6260.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6270.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6280.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6290.pth
# 6300_-15.6732_-9.3921_pen=9.216e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6300.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6310.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6320.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6330.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6340.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6350.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6360.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6370.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6380.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6390.pth
# 6400_-15.7187_-11.2707_pen=8.775e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6400.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6410.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6420.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6430.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6440.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6450.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6460.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6470.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6480.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6490.pth
# 6500_-15.7623_-12.6326_pen=8.392e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6500.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6510.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6520.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6530.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6540.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6550.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6560.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6570.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6580.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6590.pth
# 6600_-15.8033_-13.5216_pen=8.049e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6600.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6610.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6620.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6630.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6640.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6690.pth
# 6700_-15.8398_-14.0722_pen=7.747e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6790.pth
# 6800_-15.8679_-14.4142_pen=7.506e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6800.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6810.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6820.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6830.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6840.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6850.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6860.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6870.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6880.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6890.pth
# 6900_-15.8861_-14.6206_pen=7.334e-04
# Saved model to /home/stephen/grokking/grok_1764704097/6900.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/6990.pth
# 7000_-15.8989_-14.7455_pen=7.216e-04
# Saved model to /home/stephen/grokking/grok_1764704097/7000.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7010.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7020.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7030.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7040.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7050.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7060.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7070.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7080.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7090.pth
# 7100_-15.9070_-14.8195_pen=7.135e-04
# Saved model to /home/stephen/grokking/grok_1764704097/7100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7190.pth
# 7200_-15.9113_-14.8633_pen=7.076e-04
# Saved model to /home/stephen/grokking/grok_1764704097/7200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/7210.pth
# ...
# Saved model to /home/stephen/grokking/grok_1764704097/17650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17690.pth
# 17700_-15.9797_-15.1964_pen=7.152e-04
# Saved model to /home/stephen/grokking/grok_1764704097/17700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17790.pth
# 17800_-15.9994_-15.2319_pen=6.753e-04
# Saved model to /home/stephen/grokking/grok_1764704097/17800.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17810.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17820.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17830.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17840.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17850.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17860.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17870.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17880.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17890.pth
# 17900_-15.9990_-15.2314_pen=6.573e-04
# Saved model to /home/stephen/grokking/grok_1764704097/17900.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/17990.pth
# 18000_-15.9949_-15.2295_pen=6.501e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18000.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18010.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18020.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18030.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18040.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18050.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18060.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18070.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18080.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18090.pth
# 18100_-15.9899_-15.2308_pen=6.477e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18190.pth
# 18200_-15.9870_-15.2286_pen=6.473e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18210.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18220.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18230.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18240.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18250.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18260.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18270.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18280.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18290.pth
# 18300_-15.9832_-15.2299_pen=6.477e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18300.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18310.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18320.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18330.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18340.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18350.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18360.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18370.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18380.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18390.pth
# 18400_-15.9788_-15.2376_pen=6.492e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18400.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18410.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18420.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18430.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18440.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18450.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18460.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18470.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18480.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18490.pth
# 18500_-15.9761_-15.2419_pen=6.525e-04
# Saved model to /home/stephen/grokking/grok_1764704097/18500.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18510.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18520.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18530.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18540.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18550.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18560.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18570.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18580.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18590.pth
# 18600_-7.4067_-5.2817_pen=1.009e-03
# Saved model to /home/stephen/grokking/grok_1764704097/18600.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18610.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18620.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18630.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18640.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18690.pth
# 18700_-7.0655_-6.7358_pen=1.132e-03
# Saved model to /home/stephen/grokking/grok_1764704097/18700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18790.pth
# 18800_-6.9100_-6.6137_pen=1.908e-03
# Saved model to /home/stephen/grokking/grok_1764704097/18800.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18810.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18820.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18830.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18840.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18850.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18860.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18870.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18880.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18890.pth
# 18900_-7.7318_-7.3146_pen=2.878e-03
# Saved model to /home/stephen/grokking/grok_1764704097/18900.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/18990.pth
# 19000_-8.7325_-8.1606_pen=3.759e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19000.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19010.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19020.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19030.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19040.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19050.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19060.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19070.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19080.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19090.pth
# 19100_-9.7622_-9.0056_pen=4.456e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19100.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19110.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19120.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19130.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19140.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19150.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19160.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19170.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19180.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19190.pth
# 19200_-10.7953_-9.8306_pen=4.824e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19200.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19210.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19220.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19230.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19240.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19250.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19260.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19270.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19280.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19290.pth
# 19300_-11.8110_-10.6419_pen=4.697e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19300.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19310.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19320.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19330.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19340.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19350.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19360.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19370.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19380.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19390.pth
# 19400_-12.7841_-11.4129_pen=4.076e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19400.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19410.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19420.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19430.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19440.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19450.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19460.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19470.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19480.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19490.pth
# 19500_-13.6820_-12.1233_pen=3.187e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19500.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19510.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19520.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19530.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19540.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19550.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19560.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19570.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19580.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19590.pth
# 19600_-14.4627_-12.8676_pen=2.276e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19600.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19610.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19620.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19630.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19640.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19650.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19660.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19670.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19680.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19690.pth
# 19700_-15.0869_-13.6213_pen=1.570e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19700.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19710.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19720.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19730.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19740.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19750.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19760.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19770.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19780.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19790.pth
# 19800_-15.5319_-14.2905_pen=1.121e-03
# Saved model to /home/stephen/grokking/grok_1764704097/19800.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19810.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19820.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19830.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19840.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19850.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19860.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19870.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19880.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19890.pth
# 19900_-15.8073_-14.7586_pen=8.723e-04
# Saved model to /home/stephen/grokking/grok_1764704097/19900.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19910.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19920.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19930.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19940.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19950.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19960.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19970.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19980.pth
# Saved model to /home/stephen/grokking/grok_1764704097/19990.pth
# Saved model to /home/stephen/grokking/grok_1764704097/final.pth

# %% [markdown]
# ## Viz Results

# %%
CHILL_BROWN='#948979'
YELLOW='#ffd35a'
YELLOW_FADE='#7f6a2d'
BLUE='#65c8d0'
GREEN='#6e9671' 
CHILL_GREEN='#6c946f'
CHILL_BLUE='#3d5c6f'
FRESH_TAN='#dfd0b9'
CYAN='#00FFFF'

# %%
plt.plot(train_accs)
plt.plot(test_accs)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs[:500], c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs[:500], c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
plt.clf()        
fig=plt.figure(0,(14,6), facecolor='k') 
ax=fig.add_subplot(111, facecolor='k')

plt.plot(train_accs, c=BLUE, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.plot(test_accs, c=YELLOW, linewidth=2.5, alpha=0.95) #'#dfd0b9')
plt.tick_params(axis='x', colors='#948979', labelsize=16)  # Add labelsize here
plt.tick_params(axis='y', colors='#948979', labelsize=16)  # Add labelsize here

plt.gca().spines['top'].set_color('#948979')
plt.gca().spines['bottom'].set_color('#948979')
plt.gca().spines['left'].set_color('#948979')
plt.gca().spines['right'].set_color('#948979')
plt.subplots_adjust(bottom=0.2)  # Add fixed bottom margin
# plt.xlim([-10, len(to_plot)+10])
plt.ylim([0,1.05]) #Bad idea to fix or is it fine?
plt.grid(True, color='#948979', alpha=0.3)

# %%
from tqdm import tqdm

# %%
all_data = torch.tensor([(i, j, p) for i in range(p) for j in range(p)]).to('cuda')
labels = torch.tensor([fn(i, j) for i, j, _ in all_data]).to('cuda')
cache = {}
model.remove_all_hooks()
model.cache_all(cache)
# Final position only
original_logits = model(all_data)[:, -1]
# Remove equals sign from output logits
original_logits = original_logits[:, :-1]
original_loss = cross_entropy_high_precision(original_logits, labels)
print(f"Original loss: {original_loss.item()}")

#Ok let's try pre -> the og. 
mr = einops.rearrange(cache['blocks.0.mlp.hook_pre'], "(x y) ... -> x y ...", x=p).detach().cpu().numpy() 

# np.save(str(root/run_name)+'/mlp_hook_pre', mr)
# Out:
# Original loss: 2.554932213852095e-07

# %%
# ---- Helper for classifying term type ----
def classify_term_type(kx, ky, is_dc):
    if is_dc:
        return "dc"
    if kx != 0 and ky == 0:
        return "row"
    if kx == 0 and ky != 0:
        return "col"
    if kx == 0 and ky == 0:
        return "dc"
    return "cross"  # kx != 0 and ky != 0


# ---- Loop over neurons and build DataFrame ----
all_rows = []

for neuron_idx in tqdm(range(512)):
    # 113 x 113 slice for this neuron
    m_slice = mr[:, :, 2, neuron_idx]

    components, Nx, Ny = compute_frequency_components(m_slice)
    terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)

    # Max amplitude (non-DC) for this neuron, for "strong" comparison later
    non_dc_terms = [t for t in terms if not t.get("is_dc", False)]
    max_amp = max((t["amplitude"] for t in non_dc_terms), default=0.0)

    for rank, t in enumerate(terms):
        is_dc = t.get("is_dc", False)
        kx = t["kx"]
        ky = t["ky"]
        amp = t["amplitude"]
        phase = t["phase"]

        term_type = classify_term_type(kx, ky, is_dc)

        all_rows.append({
            "neuron_idx": neuron_idx,
            "term_rank": rank,          # 0 = DC if include_dc=True
            "is_dc": is_dc,
            "term_type": term_type,     # "dc", "row", "col", "cross"
            "kx": kx,
            "ky": ky,
            "amplitude": amp,
            "phase": phase,
            "max_amp_neuron": max_amp,  # per neuron
        })

df = pd.DataFrame(all_rows)
df['relative_amplitude']=df['amplitude']/df['max_amp_neuron']
# Out:
# 100%|██████████████████████| 512/512 [00:22<00:00, 22.51it/s]

# %%
df['kx'].value_counts()
# Out:
# kx
# 0     1153
# 17     840
# 5      273
# 3      266
# 34      13
# 6       11
# 10       4
# Name: count, dtype: int64

# %%
dff=df[df['kx']==6]
dff=dff[dff['ky']==6]

# %%
dff.sort_values(by='relative_amplitude', ascending=False)[:15]
# Out:
# Empty DataFrame
# Columns: [neuron_idx, term_rank, is_dc, term_type, kx, ky, amplitude, phase, max_amp_neuron, relative_amplitude]
# Index: []

# %%
neuron_idx=236
FT = np.fft.fft2(mr[:,:,2,neuron_idx])

components, Nx, Ny = compute_frequency_components(mr[:,:,2,neuron_idx])
terms = components_to_terms(components, Nx, Ny, num_freqs=4, include_dc=True)
code_str = generate_python_reconstructor(terms, Nx, Ny,
                                         func_name="approx_M",
                                         decimals=3)
print(code_str)
# Out:
# def approx_M(i, j):
#     val = 0.443
#     val += 0.692 * np.cos(2*np.pi*((17*i)/113) + -0.011)
#     val += 0.692 * np.cos(2*np.pi*((17*j)/113) + -0.014)
#     val += 0.171 * np.cos(2*np.pi*((17*i)/113) + 0.137) * np.cos(2*np.pi*((17*j)/113) + 0.137)
#     val += 0.101 * np.cos(2*np.pi*((34*j)/113) + -2.969)
#     return val

# %%
def approx_M(i, j):
    val = 0.699
    val += 0.272 * np.cos(2*np.pi*((5*i)/113) + 0.048) * np.cos(2*np.pi*((5*j)/113) + 0.048)
    val += 0.178 * np.cos(2*np.pi*((5*i)/113) + 0.0) * np.cos(2*np.pi*((108*j)/113) + 0.0)
    val += 0.128 * np.cos(2*np.pi*((10*i)/113) + -3.075)
    val += 0.128 * np.cos(2*np.pi*((10*j)/113) + -3.075)
    return val

# %%
m_approx=np.zeros((p,p))
for i in range(p):
    for j in range(p):
        m_approx[i,j]=approx_M(i,j)

fig=plt.figure(0, (12, 6))
fig.add_subplot(1,3,1); plt.imshow(mr[:,:,2,neuron_idx]); plt.axis('off')
fig.add_subplot(1,3,2); plt.imshow(np.abs(FT));  plt.axis('off')
fig.add_subplot(1,3,3); plt.imshow(m_approx); plt.axis('off');
