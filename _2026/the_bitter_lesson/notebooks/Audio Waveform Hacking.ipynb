# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# fn='/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/a_roll/260112_001_Tr1.WAV'
fn='/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/exports/tell_me_about_china.wav'

# %%
from scipy.io import wavfile

sample_rate, data = wavfile.read(fn)
# Out:
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_2036/2235076078.py:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, data = wavfile.read(fn)

# %%
data.shape, sample_rate
# Out:
# ((62463,), 48000)

# %%
data
# Out:
# array([-21, -24, -23, ...,  -9,  -8,   0], dtype=int16)

# %%
len(data)
# Out:
# 62463

# %%
plt.plot(data)

# %%
plt.plot(data[::2])

# %%
CHILL_BROWN='#948979'

fig=plt.figure(0, (12,2), facecolor='k')
ax=fig.add_subplot(111, facecolor='k')
plt.plot(data[375000:440000], color='#00FFFF')

# Spines
for spine in ax.spines.values():
    spine.set_color(CHILL_BROWN)

# Ticks and tick labels
ax.tick_params(colors=CHILL_BROWN)

# If you have axis labels
ax.xaxis.label.set_color(CHILL_BROWN)
ax.yaxis.label.set_color(CHILL_BROWN)

# If you have a title
ax.title.set_color(CHILL_BROWN)
# plt.grid()
plt.axis('off')
# Out:
# (-3249.9500000000003, 68248.95, -0.09056357853114605, 0.09578864835202694)

# %%
spectra_path='/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/hacking/spectral_envelopes_final.npy'
spectra=np.load(spectra_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 spectra_path='/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/hacking/spectral_envelopes_final.npy'
# ----> 2 spectra=np.load(spectra_path)
#
# File /opt/anaconda3/lib/python3.11/site-packages/numpy/lib/npyio.py:456, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     453         return format.open_memmap(file, mode=mmap_mode,
#     454                                   max_header_size=max_header_size)
#     455     else:
# --> 456         return format.read_array(fid, allow_pickle=allow_pickle,
#     457                                  pickle_kwargs=pickle_kwargs,
#     458                                  max_header_size=max_header_size)
#     459 else:
#     460     # Try a pickle
#     461     if not allow_pickle:
#
# ...
