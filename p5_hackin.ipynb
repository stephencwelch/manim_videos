# %%
# %pylab inline
from pathlib import Path
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
data_dir=Path('/Users/stephen/Stephencwelch Dropbox/welch_labs/bitter_lesson/hacking/spectra')

s={}
for p in data_dir.glob('*.npy'):
    s[p.stem]=np.load(p)

# %%
s.keys()
# Out:
# dict_keys(['spectrum_me_iy', 'spectrum_show_sh', 'spectrum_please_iy', 'spectrum_me_m', 'spectrum_please_z', 'spectrum_please_l', 'freq', 'spectrum_show_ow', 'spectrum_please_p'])

# %%
s['freq'].shape
# Out:
# (8192,)

# %%
s['spectrum_please_p'].shape
# Out:
# (8192,)

# %%
plt.plot(s['freq'], s['spectrum_please_p'])

# %% [markdown]
# Ok these look great - 50/50 on manim vs matplotlib here.
